# %%
import pandas as pd
import numpy as np

# %%
df_pres = pd.read_csv('pres.csv')
df_pres
# Out:
#     Unnamed: 0  Code du département  Inscrits  Abstentions   Votants  \
# 0           15                   16    257608      59909.0  197699.0
# 1           16                   17    519202     116437.0  402765.0
# 2           18                   19    185032      38430.0  146602.0
# 3           23                   23     90946      21967.0   68979.0
# 4           24                   24    318168      64856.0  253312.0
# ..         ...                  ...       ...          ...       ...
# 67          47                   47    224985      39974.0  185011.0
# 68          64                   64    432701      87421.0  345280.0
# 69          79                   79    259259      47609.0  211650.0
# 70          86                   86    281401      53594.0  227807.0
# 71          87                   87    263199      44722.0  218477.0
#
#     Extreme Gauche  Gauche  Droite  Extreme Droite  Autre        Election  \
# ...

# %%
df_eur = pd.read_csv('eur.csv')
df_eur
# Out:
#     Unnamed: 0  Code du département  Inscrits  Abstentions  Votants  \
# 0           15                   16    257530       122232   135298
# 1           16                   17    493475       226887   266588
# 2           18                   19    183950        81436   102514
# 3           23                   23     92094        42981    49113
# 4           24                   24    314086       131059   183027
# ..         ...                  ...       ...          ...      ...
# 67          47                   47    222860        90072   132788
# 68          64                   64    425221       191945   233276
# 69          79                   79    256710       118155   138555
# 70          86                   86    276419       126176   150243
# 71          87                   87    261414       107622   153792
#
#     Extreme Gauche  Gauche  Droite  Extreme Droite  Autre    Election  Année
# ...

# %%
df_leg = pd.read_csv('leg.csv')
df_leg
# Out:
#     Unnamed: 0  Code du département  Inscrits  Abstentions   Votants  \
# 0           15                   16    258374     128661.0  129713.0
# 1           16                   17    520944     259513.0  261431.0
# 2           18                   19    185569      81491.0  104078.0
# 3           23                   23     91035      41508.0   49527.0
# 4           24                   24    319328     143379.0  175949.0
# ..         ...                  ...       ...          ...       ...
# 67          47                   47    221220      60352.0  160868.0
# 68          64                   64    429756     134996.0  294760.0
# 69          79                   79    256065      72702.0  183363.0
# 70          86                   86    277872      83481.0  194391.0
# 71          87                   87    258709      67892.0  190817.0
#
#     Extreme Gauche  Gauche  Droite  Extreme Droite  Autre     Election  Année
# ...

# %%
df_election =  pd.concat([df_pres,df_leg,df_eur], axis=0)
df_election
# Out:
#     Unnamed: 0  Code du département  Inscrits  Abstentions   Votants  \
# 0           15                   16    257608      59909.0  197699.0
# 1           16                   17    519202     116437.0  402765.0
# 2           18                   19    185032      38430.0  146602.0
# 3           23                   23     90946      21967.0   68979.0
# 4           24                   24    318168      64856.0  253312.0
# ..         ...                  ...       ...          ...       ...
# 67          47                   47    222860      90072.0  132788.0
# 68          64                   64    425221     191945.0  233276.0
# 69          79                   79    256710     118155.0  138555.0
# 70          86                   86    276419     126176.0  150243.0
# 71          87                   87    261414     107622.0  153792.0
#
#     Extreme Gauche  Gauche  Droite  Extreme Droite  Autre        Election  \
# ...

# %%
df_election["Abstentions"].values
# Out:
# array([ 59909., 116437.,  38430.,  21967.,  64856., 249014.,  65654.,
#         52907., 110134.,  59403.,  68304.,  55484.,  54980.,  99354.,
#         34299.,  19917.,  57520., 216588.,  55411.,  46805.,  97357.,
#         50961.,  62127.,  50620.,  46641.,  85478.,  27332.,  17218.,
#         47286., 174717.,  48073.,  40306.,  86788.,  43596.,  52557.,
#         41025.,  39588.,  68782.,  24314.,  16523.,  36115., 119988.,
#         34886.,  30536.,  60849.,  34999.,  42567.,  35189.,  67322.,
#        112588.,  37531.,  27941.,  72146., 245810.,  65026.,  57671.,
#        122016.,  63741.,  70942.,  59701.,  51067.,  83567.,  26277.,
#         22037.,  51250., 163457.,  42499.,  39974.,  87421.,  47609.,
#         53594.,  44722., 128661., 259513.,  81491.,  41508., 143379.,
#        574503., 152480., 114611., 246604., 137555., 149730., 123341.,
#        129069., 243862.,  79167.,  41723., 138269., 533587., 138746.,
# ...

# %%
df_election.to_csv('elections.csv')
