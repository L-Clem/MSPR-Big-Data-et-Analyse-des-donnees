# %%
import pandas as pd

# %%
column_names = ["Annee", "15-24 ans Femmes", "15-24 ans Hommes", "25-49 ans Femmes", "25-49 ans Hommes", "50-64 ans Femmes", "50-64 ans Hommes"]

df_taux_activ = pd.read_csv("marc-empl-nbr-taux-activ-sexe-age-taux.csv", header=7, names=column_names, delimiter=';')

df_taux_activ["Annee"] = df_taux_activ["Annee"].astype('int')
df_taux_activ["15-24 ans Femmes"] = df_taux_activ["15-24 ans Femmes"].astype('float')
df_taux_activ["15-24 ans Hommes"] = df_taux_activ["15-24 ans Hommes"].astype('float')
df_taux_activ["25-49 ans Femmes"] = df_taux_activ["25-49 ans Femmes"].astype('float')
df_taux_activ["25-49 ans Hommes"] = df_taux_activ["25-49 ans Hommes"].astype('float')
df_taux_activ["50-64 ans Femmes"] = df_taux_activ["50-64 ans Femmes"].astype('float')
df_taux_activ["50-64 ans Hommes"] = df_taux_activ["50-64 ans Hommes"].astype('float')

# %%
df_taux_activ
# Out:
#     Année  15-24 ans Femmes  15-24 ans Hommes  25-49 ans Femmes  \
# 0    2015              35.3              41.7              84.4
# 1    2014              34.6              41.0              84.7
# 2    2013              35.2              41.8              84.9
# 3    2012              35.0              41.8              84.3
# 4    2011              35.6              42.2              84.5
# 5    2010              36.3              43.6              84.9
# 6    2009              37.4              43.8              84.7
# 7    2008              35.7              43.1              84.5
# 8    2007              35.9              42.8              83.7
# 9    2006              35.4              43.0              83.2
# 10   2005              35.3              43.0              82.9
# 11   2004              35.4              43.0              82.6
# 12   2003              35.1              43.0              82.3
# 13   2002              34.1              42.2              82.2
# ...
