# %%
import pandas as pd

# %%
df = pd.read_excel("16.xlsx",skiprows=3)
df=df.rename(columns={"Période":"Année","Unnamed: 1":"taux-mortalite"})
df
# Out:
# /Users/alisaleh/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     Année  taux-mortalite
# 0    2023            12.7
# 1    2022            13.3
# 2    2021            12.8
# 3    2020            12.2
# 4    2019            12.3
# 5    2018            12.0
# 6    2017            11.9
# 7    2016            11.6
# 8    2015            11.8
# 9    2014            10.6
# 10   2013            11.2
# 11   2012            11.2
# 12   2011            10.8
# 13   2010            10.7
# 14   2009            11.2
# 15   2008            10.5
# 16   2007            10.0
# 17   2006            10.5
# 18   2005            10.7
# 19   2004            10.4
# 20   2003            11.2
# 21   2002            11.0
# 22   2001            11.3
# 23   2000            10.8
# 24   1999            11.0
# 25   1998            11.2
# ...

# %%
departement_code= ['16','17','19','23','24','33','40','47','64','79','86','87']
df_passing_dep = []
for dep in departement_code :
    file= dep+".xlsx"
    df= pd.read_excel(file,skiprows=3)
    df =df.rename(columns={"Période":"Année","Unnamed: 1":"taux-mortalite"})
    df["Code du département"] =dep
    df_passing_dep.append(df)
len(df_passing_dep)
df_passing_dep[3]
# Out:
# /Users/alisaleh/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/alisaleh/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/alisaleh/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/alisaleh/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df_concat =  pd.concat(df_passing_dep)
df_concat
# Out:
#     Année  taux-mortalite Code du département
# 0    2023            12.7                  16
# 1    2022            13.3                  16
# 2    2021            12.8                  16
# 3    2020            12.2                  16
# 4    2019            12.3                  16
# ..    ...             ...                 ...
# 44   1979            12.8                  87
# 45   1978            12.6                  87
# 46   1977            12.5                  87
# 47   1976            12.4                  87
# 48   1975            12.8                  87
#
# [588 rows x 3 columns]

# %%
df_concat.to_csv("taux-mortalite.csv")
